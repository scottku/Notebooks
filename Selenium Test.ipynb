# %%
# Selenium : 웹 페이지가 실제 브라우저에서 오류 없이 잘 작동하는가 테스트 하는 도구
# 1. Selenium 모듈 설치 : pip install selenium
# 2. 브라우저 드라이버
# 브라우저 버전 확인 (메뉴 -> 설정 -> chrome 정보)

from selenium import webdriver

# 드라이버 로드
driver = webdriver.Chrome("e:/Coding_Utilities/chromedriver.exe")
# 접속
driver.get("https://www.naver.com")
# 페이지 로드 전에 약간의 시간 필요
driver.implicitly_wait(3)

# #account > a -> 클릭
btn_login = driver.find_element_by_css_selector("#account > a") # 요소를 찾고
btn_login.click() # 클릭 이벤트 발생

# 아이디 입력창 xpath: //*[@id = "id"]
input_id = driver.find_element_by_xpath("//*[@id = \"id\"]") # 아이디 입력창 찾고
# 아이디 입력 이벤트 발생
input_id.send_keys("9qhswo")
# 비밀번호 입력창 xpath: //*[@id="pw"]
input_pw = driver.find_element_by_xpath("//*[@id=\"pw\"]")
# 비밀번호 입력 이벤트 발생
input_pw.send_keys("password")
# 로그인 버튼 xpath: //*[@id="log.login"]
btn_submit = driver.find_element_by_xpath("//*[@id=\"log.login\"]")
#btn_submit.click()

# %%
# 1. naver.com 접속
# 2. 검색어 입력
# 3. 검색 버튼 클릭
# 4. 검색 결과 소스 HTML 확인
driver = webdriver.Chrome("e:/Coding_Utilities/chromedriver.exe")

driver.get("http://www.naver.com")
driver.implicitly_wait(3)
# 검색어 창 selector : #query
# 검색 버튼 selector : #search_btn
input_search = driver.find_element_by_css_selector("#query")
input_search.send_keys("코로나 증상")
btn_search = driver.find_element_by_css_selector("#search_btn")
btn_search.click()

# 결과 페이지 소스 확인
result = driver.page_source
print(result) # 크롤링 대상 페이지 소스
# BeautifulSoup으로 분석, 스크래핑
# Out:
# <html lang="ko" data-useragent="mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/91.0.4472.77 safari/537.36" data-platform="win32"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="코로나 증상 : 네이버 통합검색"> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'코로나 증상'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'코로나 증상'의 네이버 통합검색 결과입니다."> <title>코로나 증상 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver"><link rel="s
# ...
